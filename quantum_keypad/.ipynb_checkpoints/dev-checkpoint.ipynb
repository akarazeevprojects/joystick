# %%
# %load_ext autoreload
# %autoreload 2
import utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import socket
import sys
import time
import numpy as np


s = utils.State()

use_blank = False

presses = []
utils.find_pattern(s, presses, blank=use_blank)

presses.append(69)
presses.append(77)
presses.append(69)
presses = utils.find_pattern(s, presses, blank=use_blank)

presses.append(75)
presses = utils.find_pattern(s, presses, blank=use_blank)

presses.append(1)
presses = utils.find_pattern(s, presses, blank=use_blank)
# Out:
# q[0]  |0> -- -- -- -- -- -- -- Mz┐
#           ^^                     |
# q[1]  |0> -- -- -- -- -- -- -- --|Mz┐
#                                  |  |
# c.reg. 0-/-----------------------v--v-
#                                  0  1
# q[0]  |0> -- -- -- -- -- -- -- Mz┐
#              ^^                  |
# q[1]  |0> -- -- -- -- -- -- -- --|Mz┐
#                                  |  |
# c.reg. 0-/-----------------------v--v-
#                                  0  1
# q[0]  |0> -- H  -- -- -- -- -- Mz┐
#              ^^                  |
# q[1]  |0> -- -- -- -- -- -- -- --|Mz┐
#                                  |  |
# c.reg. 0-/-----------------------v--v-
#                                  0  1
# Key 1 is not recognized
